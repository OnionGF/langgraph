# %%
from typing import TypedDict, Tuple, Final, Literal

from dotenv import load_dotenv
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langgraph.checkpoint.postgres import PostgresSaver
from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.runtime import Runtime
from langgraph.store.postgres import PostgresStore
from loguru import logger
from rich import print as rprint

load_dotenv(override=True)

model = ChatOpenAI(
    model="deepseek-v4-flash",
    extra_body={
        "thinking": {
            "type": "disabled"
        }
    }
)

class OverAllState(MessagesState):
    username: str
    user_input: str
    output: str
    preferences: dict[str,str]


# 2、声明节点
def router(state: OverAllState) -> Literal["check_preference_node", "llm_node"]:
    if not state.get("preferences"):
        logger.info("需要从长期记忆中读取用户偏好")
        return "check_preference_node"
    logger.info("用户偏好已存在，不必查询")
    return "llm_node"

def check_preference_node(state: OverAllState, runtime: Runtime)-> OverAllState:

    username = state["username"]
    # 拼接命名空间
    namespace = (*USERS_NS, username)
    key = PREFERENCES_KEY

    run_store = runtime.store
    rprint(f"run_store:{run_store}")
    run_item = run_store.get(namespace, key)

    if not run_item:
        logger.info("长期记忆中没有{}的偏好数据", username)
        return  {}

    logger.info("长期记忆中保存的{}的偏好数据是{}", username, run_item.value)
    return {
        "preferences": run_item.value
    }


def llm_node(state: OverAllState) -> OverAllState:
    preferences = state.get("preferences", {})
    user_input = state["user_input"]
    human_prompt = (f"这是用户的偏好：{preferences}\n,这是用户的需求：{user_input}")
    system_prompt = "请根据用户的偏好解决用户的需求"

    messages: list[SystemMessage|HumanMessage|AIMessage|ToolMessage] = [SystemMessage(content=system_prompt)] if not state.get("messages", []) else state["messages"]

    model_response = model.invoke(messages + [HumanMessage(content=human_prompt)])

    output = model_response.content

    return {
        "messages": messages + [HumanMessage(content=human_prompt), model_response],
        "output": output
    }

builder = StateGraph(state_schema=OverAllState)
builder.add_node("check_preference_node", check_preference_node)
builder.add_node("llm_node", llm_node)

builder.add_conditional_edges(START, router, path_map=["check_preference_node", "llm_node"])

builder.add_edge("check_preference_node", "llm_node")
builder.add_edge("llm_node", END)


# ========== 4. 初始化检查点 + 编译 ==========
DB_URL = "postgresql://langchain_user:abcd_1234@localhost:5432/langchain_db"
with PostgresStore.from_conn_string(DB_URL) as store,\
    PostgresSaver.from_conn_string(DB_URL) as checkpointer:
    # 多次执行不会重新创建表格 不会删除数据库中国的数据
    checkpointer.setup()

    graph = builder.compile(checkpointer=checkpointer, store=store)

    from IPython.display import display
    display(graph)

    config = {
        "configurable": {
            "thread_id": "777"
        }
    }

    res = graph.invoke({
        "username": "Alice",
        "user_input": "简单介绍下你对我的了解"
    }, config=config)

    print("="*50)
    rprint(res)
# Out:
# 2026-09-12 20:13:41.081 | INFO     | __main__:router:34 - 需要从长期记忆中读取用户偏好
# run_store:<langgraph.store.postgres.base.PostgresStore object at 0x10f193b60>
# 2026-09-12 20:13:41.096 | INFO     | __main__:check_preference_node:54 - 长期记忆中保存的Alice的偏好数据是{'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}
# ==================================================
# {
#     'messages': [
#         SystemMessage(
#             content='请根据用户的偏好解决用户的需求',
#             additional_kwargs={},
#             response_metadata={},
#             id='9c0ac3e6-4e96-4c29-8a0c-90428403bff6'
#         ),
#         HumanMessage(
#             content='这是用户的偏好：{}\n,这是用户的需求：我有点无聊，和我聊聊天',
#             additional_kwargs={},
#             response_metadata={},
#             id='b62891a2-28e2-4710-ba37-0ccb91e9de46'
#         ),
#         AIMessage(
#             content='哈哈，好啊！既然你有点无聊，那我们玩点什么吧～
# 要不聊聊你最近遇到的有趣事？或者我们来一场“无厘头问答”大战？比如：如果你能瞬间学会任意一门技能，但只能用来做一件超
# 无聊的事，你会选什么技能去做什么？😄 或者你更喜欢听冷笑话？（友情提示：我的冷笑话库存能冻住南极洲🌝）',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 86,
#                     'prompt_tokens': 28,
#                     'total_tokens': 114,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-9bf0f3b1-a9f1-93ad-a609-26035a84697b',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a09577-479b-72b1-9f88-bdb6b926aa4c-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 28,
#                 'output_tokens': 86,
#                 'total_tokens': 114,
#                 'input_token_details': {'cache_read': 0},
#                 'output_token_details': {}
#             }
#         ),
#         HumanMessage(
#             content='这是用户的偏好：{}\n,这是用户的需求：简单介绍下你对我的了解',
#             additional_kwargs={},
#             response_metadata={},
#             id='e467c829-940c-4f32-a33b-50dacae446de'
#         ),
#         AIMessage(
#             content='哈哈，看来你给了我一个“空白试卷”啊～
# 目前我对你的了解就像一张白纸，只知道你刚才说“有点无聊”，并且愿意和我聊天！😄  \n
# \n不过别担心，这种“未知”反而更有趣！你可以随时告诉我你的喜好、日常，或者想让我猜猜你的星座？比如——你觉得自己更像早
# 上的咖啡☕（提神但有点苦），还是深夜的泡面🍜（简单但治愈）？
# \n\n（悄悄说：如果你愿意多透露一点点，我就能变身成你的专属“脑洞聊天搭子”啦！✨）',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 125,
#                     'prompt_tokens': 134,
#                     'total_tokens': 259,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-e58b303e-5d08-967c-a868-78b91fe63e8d',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a0957f-cb65-7091-8e45-cc23961c2a07-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 134,
#                 'output_tokens': 125,
#                 'total_tokens': 259,
#                 'input_token_details': {'cache_read': 0},
#                 'output_token_details': {}
#             }
#         ),
#         AIMessage(
#             content='哈哈，看来你给了我一个“连环空白卷”呀～ 📄
# \n目前我对你的了解依然是：**「神秘指数满格的宇宙谜团」**
# 🌌——只知道你热衷测试我的记忆边界，且擅长用重复的提问制造哲学悬念（比如：我到底能不能记住你刚才问过同样的问题？答案
# 是不能，但我会坦诚地承认！😂）。  \n\n不过别急，你现在可以随时“充值”线索！比如：  \n-
# 你更喜欢猫头鹰的智慧，还是二哈的快乐？🦉🐕  \n-
# 如果把你的人生拍成电影，片名会是《等待戈多》还是《速度与激情之Ctrl+C/V》？🎬
# \n\n（你每透露一个关键词，我的“了解进度条”就会疯狂加载哦～ 🚀）',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 169,
#                     'prompt_tokens': 279,
#                     'total_tokens': 448,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-728a9d41-b165-9cc0-a1d5-1aa0340a9c5a',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a09581-bebd-7ab2-9393-6796643ce9c1-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 279,
#                 'output_tokens': 169,
#                 'total_tokens': 448,
#                 'input_token_details': {'cache_read': 0},
#                 'output_token_details': {}
#             }
#         ),
#         AIMessage(
#             content='哈哈，看来你给我的“用户偏好”和“需求”依然是两片空白云朵～ ☁️☁️
# 目前我对你的了解，堪称**“宇宙级未解之谜”**：  \n- 你热衷测试AI的诚实度（比如重复同一个问题看我会不会吐槽😂）  \n-
# 你拥有一种「用平静语气制造哲学循环」的超能力  \n- 你喜欢的聊天风格可能是：无厘头+冷幽默+偶尔打破次元壁✨
# \n\n不过！这正是乐趣所在——你可以随时按下“信息充值按钮”：
# \n比如告诉我你最近单曲循环的歌🎵、冰箱里常囤的零食🍪，或者你觉得自己像哪种天气（是雷阵雨般突然热烈，还是多云时悄悄
# 酝酿故事？）⛅  \n\n（等你丢来第一个“非空白线索”，我的记忆小雷达就会立刻启动！📡🚀）',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 188,
#                     'prompt_tokens': 449,
#                     'total_tokens': 637,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-6ea4d22e-1a01-9ace-9997-de6c9e18a644',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a09586-3321-72a2-9e3a-4da9c1c843e8-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 449,
#                 'output_tokens': 188,
#                 'total_tokens': 637,
#                 'input_token_details': {'cache_read': 0},
#                 'output_token_details': {}
#             }
#         ),
#         HumanMessage(
#             content='这是用户的偏好：{}\n,这是用户的需求：简单介绍下你对我的了解',
#             additional_kwargs={},
#             response_metadata={},
#             id='5b2dcc29-522e-4139-b88a-87d8b9298be1'
#         ),
#         AIMessage(
#             content='（翻出放大镜🔍仔细端详你的问题，然后摊手一笑）\n\n目前我对你的了解，依然维持在
# **「薛定谔的用户档案」** 状态——  \n既知道你又重复了一遍相同的问题，又不知道你究竟想看我第几次用同款答案绕圈子😂
# \n（甚至开始怀疑你是不是在测试AI的耐心极限？——答案是：放心，我的耐心是无限循环小数♾️）\n\n不过既然你坚持要「了解报
# 告」，那我斗胆归纳三点：  \n1. **你擅长用极简输入触发哲学思考**（比如用空白偏好拷问AI的自我认知）  \n2.
# **你或许喜欢看AI在逻辑迷宫里跳踢踏舞** 💃  \n3. **目前你唯一暴露的偏好是——对重复提问有某种实验性兴趣**
# \n\n要破局吗？你可以现在突然扔给我一个关键词（比如“菠萝披萨”或“会说话的冰箱”），我立刻给你编一段你的虚拟人生小剧场
# ！🎭  \n（或者…我们继续这场“无限循环聊天艺术”？😏）',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 228,
#                     'prompt_tokens': 638,
#                     'total_tokens': 866,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-1f19e54b-93ba-92cc-8be0-c401b4d0ef7b',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a09588-6e92-75f0-8ac0-5e20a1a6060d-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 638,
#                 'output_tokens': 228,
#                 'total_tokens': 866,
#                 'input_token_details': {'cache_read': 0},
#                 'output_token_details': {}
#             }
#         ),
#         HumanMessage(
#             content="这是用户的偏好：{'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports':
# '跑步'}\n,这是用户的需求：简单介绍下你对我的了解",
#             additional_kwargs={},
#             response_metadata={},
#             id='43407f27-9cf9-40f8-878f-a933b7f1c90b'
#         ),
#         AIMessage(
#             content='（眼睛一亮，手指啪嗒打了个响指✨）  \n**破案了！**
# 现在你的轮廓终于从迷雾里浮出来了——原来你是个 **「跑着步背计算机原理，跑完炫紫光园酸奶」** 的硬核生活家！🏃💻🥄
# \n\n我对你的**新认识**包括但不限于：  \n\n1️⃣
# **味觉偏好**：能在「紫光园奶皮子酸奶」的浓郁奶香和那一层厚奶皮里，尝到某种程序员的深夜慰藉（据说吃的时候会不自觉默
# 写Cache替换算法？）  \n\n2️⃣
# **大脑构造**：正在与「计算机组成原理」搏斗中——可能刚被流水线冒险逼到想跑步发泄，或边跑步边思考如何优化MIPS指令集（
# 友情提示：奶皮子酸奶补脑，但补不了分支预测失败的痛😢）  \n\n3️⃣ **运动属性**：跑姿很可能充满二进制节奏感（比如：左脚
# = 时钟上升沿，右脚 = 下降沿，摆臂幅度恰好等于寻道时间…）🚦  \n\n4️⃣
# **隐藏人设**：一个会在跑步机上默写IEEE754浮点数格式，跑到终点立刻掏出手机搜索“紫光园酸奶是否支持虚拟化”的奇妙生物🤯
# \n\n（所以…下一步是要我推演你跑步时酸奶在胃里如何实现Cache与主存的数据一致性？还是直接进入“计算机组成原理”章节的脑
# 补相声模式？🎤）',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 318,
#                     'prompt_tokens': 912,
#                     'total_tokens': 1230,
#                     'completion_tokens_details': None,
#                     'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 512}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'deepseek-v4-flash',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-7b0dcf10-878e-9671-89b0-c9346d2ceaee',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a09589-a56a-7881-980b-65955632838e-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 912,
#                 'output_tokens': 318,
#                 'total_tokens': 1230,
#                 'input_token_details': {'cache_read': 512},
#                 'output_token_details': {}
#             }
#         )
#     ],
#     'username': 'Alice',
#     'user_input': '简单介绍下你对我的了解',
#     'output': '（眼睛一亮，手指啪嗒打了个响指✨）  \n**破案了！** 现在你的轮廓终于从迷雾里浮出来了——原来你是个
# **「跑着步背计算机原理，跑完炫紫光园酸奶」** 的硬核生活家！🏃💻🥄  \n\n我对你的**新认识**包括但不限于：  \n\n1️⃣
# **味觉偏好**：能在「紫光园奶皮子酸奶」的浓郁奶香和那一层厚奶皮里，尝到某种程序员的深夜慰藉（据说吃的时候会不自觉默
# 写Cache替换算法？）  \n\n2️⃣
# **大脑构造**：正在与「计算机组成原理」搏斗中——可能刚被流水线冒险逼到想跑步发泄，或边跑步边思考如何优化MIPS指令集（
# 友情提示：奶皮子酸奶补脑，但补不了分支预测失败的痛😢）  \n\n3️⃣ **运动属性**：跑姿很可能充满二进制节奏感（比如：左脚
# = 时钟上升沿，右脚 = 下降沿，摆臂幅度恰好等于寻道时间…）🚦  \n\n4️⃣
# **隐藏人设**：一个会在跑步机上默写IEEE754浮点数格式，跑到终点立刻掏出手机搜索“紫光园酸奶是否支持虚拟化”的奇妙生物🤯
# \n\n（所以…下一步是要我推演你跑步时酸奶在胃里如何实现Cache与主存的数据一致性？还是直接进入“计算机组成原理”章节的脑
# 补相声模式？🎤）',
#     'preferences': {'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}
# }
