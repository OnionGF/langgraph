# %%
# left: 从最开始的位置合并到当前节点位置的值
# right: 当前节点的值
# 返回值：合并后的值
def my_reducer(left: list[str], right: list[str]) -> list[str]:
    return left + right

left = ["start","node_1 运行完毕"]
right = ["node2_运行完毕"]

merged = my_reducer(left, right)

print(merged)
# Out:
# ['start', 'node_1 运行完毕', 'node2_运行完毕']
