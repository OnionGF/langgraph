# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
from rich import print as rprint

class OverAllState(TypedDict):
    initial_state: str
    node_a_output: str
    node_b_output: str

def node_a(state: OverAllState) -> OverAllState:
    return {
        "node_a_output": "节点A的输出"
    }

def node_b(state: OverAllState) -> OverAllState:
    return {
        "node_b_output": "节点B的输出"
    }

builder = StateGraph(state_schema=OverAllState)
builder.add_node("node_a", node_a)
builder.add_node("node_b", node_b)
builder.add_edge(START, "node_a")
builder.add_edge("node_a", "node_b")
builder.add_edge("node_b", END)

graph = builder.compile()
async for chunk in graph.astream_events(
    {"initial_state": "初始状态"},
    version="v2"
):
    rprint(chunk)
# Out:
# {
#     'event': 'on_chain_start',
#     'data': {'input': {'initial_state': '初始状态'}},
#     'name': 'LangGraph',
#     'tags': [],
#     'run_id': '01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572',
#     'metadata': {'ls_integration': 'langgraph'},
#     'parent_ids': []
# }
# {
#     'event': 'on_chain_start',
#     'data': {'input': {'initial_state': '初始状态'}},
#     'name': 'node_a',
#     'tags': ['graph:step:1'],
#     'run_id': '01a0a2e5-6cac-7d23-b0c4-3387aa080ad5',
#     'metadata': {
#         'ls_integration': 'langgraph',
#         'langgraph_step': 1,
#         'langgraph_node': 'node_a',
#         'langgraph_triggers': ('branch:to:node_a',),
#         'langgraph_path': ('__pregel_pull', 'node_a'),
#         'langgraph_checkpoint_ns': 'node_a:953b87c2-742e-b52e-4854-6cb452fc1647'
#     },
#     'parent_ids': ['01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572']
# }
# {
#     'event': 'on_chain_stream',
#     'run_id': '01a0a2e5-6cac-7d23-b0c4-3387aa080ad5',
#     'name': 'node_a',
#     'tags': ['graph:step:1'],
#     'metadata': {
#         'ls_integration': 'langgraph',
#         'langgraph_step': 1,
#         'langgraph_node': 'node_a',
#         'langgraph_triggers': ('branch:to:node_a',),
#         'langgraph_path': ('__pregel_pull', 'node_a'),
#         'langgraph_checkpoint_ns': 'node_a:953b87c2-742e-b52e-4854-6cb452fc1647'
#     },
#     'data': {'chunk': {'node_a_output': '节点A的输出'}},
#     'parent_ids': ['01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572']
# }
# {
#     'event': 'on_chain_end',
#     'data': {'output': {'node_a_output': '节点A的输出'}, 'input': {'initial_state': '初始状态'}},
#     'run_id': '01a0a2e5-6cac-7d23-b0c4-3387aa080ad5',
#     'name': 'node_a',
#     'tags': ['graph:step:1'],
#     'metadata': {
#         'ls_integration': 'langgraph',
#         'langgraph_step': 1,
#         'langgraph_node': 'node_a',
#         'langgraph_triggers': ('branch:to:node_a',),
#         'langgraph_path': ('__pregel_pull', 'node_a'),
#         'langgraph_checkpoint_ns': 'node_a:953b87c2-742e-b52e-4854-6cb452fc1647'
#     },
#     'parent_ids': ['01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572']
# }
# {
#     'event': 'on_chain_stream',
#     'run_id': '01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572',
#     'name': 'LangGraph',
#     'tags': [],
#     'metadata': {'ls_integration': 'langgraph'},
#     'data': {'chunk': {'node_a': {'node_a_output': '节点A的输出'}}},
#     'parent_ids': []
# }
# {
#     'event': 'on_chain_start',
#     'data': {'input': {'initial_state': '初始状态', 'node_a_output': '节点A的输出'}},
#     'name': 'node_b',
#     'tags': ['graph:step:2'],
#     'run_id': '01a0a2e5-6cbb-77e3-8bc4-9ee3123db261',
#     'metadata': {
#         'ls_integration': 'langgraph',
#         'langgraph_step': 2,
#         'langgraph_node': 'node_b',
#         'langgraph_triggers': ('branch:to:node_b',),
#         'langgraph_path': ('__pregel_pull', 'node_b'),
#         'langgraph_checkpoint_ns': 'node_b:4ae302ec-aa45-777a-01f1-016fce5d8834'
#     },
#     'parent_ids': ['01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572']
# }
# {
#     'event': 'on_chain_stream',
#     'run_id': '01a0a2e5-6cbb-77e3-8bc4-9ee3123db261',
#     'name': 'node_b',
#     'tags': ['graph:step:2'],
#     'metadata': {
#         'ls_integration': 'langgraph',
#         'langgraph_step': 2,
#         'langgraph_node': 'node_b',
#         'langgraph_triggers': ('branch:to:node_b',),
#         'langgraph_path': ('__pregel_pull', 'node_b'),
#         'langgraph_checkpoint_ns': 'node_b:4ae302ec-aa45-777a-01f1-016fce5d8834'
#     },
#     'data': {'chunk': {'node_b_output': '节点B的输出'}},
#     'parent_ids': ['01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572']
# }
# {
#     'event': 'on_chain_end',
#     'data': {
#         'output': {'node_b_output': '节点B的输出'},
#         'input': {'initial_state': '初始状态', 'node_a_output': '节点A的输出'}
#     },
#     'run_id': '01a0a2e5-6cbb-77e3-8bc4-9ee3123db261',
#     'name': 'node_b',
#     'tags': ['graph:step:2'],
#     'metadata': {
#         'ls_integration': 'langgraph',
#         'langgraph_step': 2,
#         'langgraph_node': 'node_b',
#         'langgraph_triggers': ('branch:to:node_b',),
#         'langgraph_path': ('__pregel_pull', 'node_b'),
#         'langgraph_checkpoint_ns': 'node_b:4ae302ec-aa45-777a-01f1-016fce5d8834'
#     },
#     'parent_ids': ['01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572']
# }
# {
#     'event': 'on_chain_stream',
#     'run_id': '01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572',
#     'name': 'LangGraph',
#     'tags': [],
#     'metadata': {'ls_integration': 'langgraph'},
#     'data': {'chunk': {'node_b': {'node_b_output': '节点B的输出'}}},
#     'parent_ids': []
# }
# {
#     'event': 'on_chain_end',
#     'data': {
#         'output': {'initial_state': '初始状态', 'node_a_output': '节点A的输出', 'node_b_output': '节点B的输出'}
#     },
#     'run_id': '01a0a2e5-6ca1-79b1-b36f-5a2dcce2a572',
#     'name': 'LangGraph',
#     'tags': [],
#     'metadata': {'ls_integration': 'langgraph'},
#     'parent_ids': []
# }
